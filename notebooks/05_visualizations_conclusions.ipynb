# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 05 — Visualisations and Conclusions\n",
    "**Stage 7: Interpretation and Communication**\n",
    "\n",
    "Generates all 10 publication-quality charts and summarises\n",
    "the final answer to our research question."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "import sys\n",
    "sys.path.insert(0, '..')\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "from config import DATA_PROC_DIR, FIGURES_DIR\n",
    "from src.collectors.data_fetcher import extract_top4\n",
    "from src.visualizers.eda_plots import (\n",
    "    plot_ga_distribution, plot_correlation_heatmap,\n",
    "    plot_ga_vs_points_scatter, plot_champion_def_rank_heatmap\n",
    ")\n",
    "from src.visualizers.league_plots import (\n",
    "    plot_top4_defensive_bars, plot_champion_ga_trend,\n",
    "    plot_defensive_radar\n",
    ")\n",
    "from src.visualizers.summary_plots import (\n",
    "    plot_hypothesis_summary_bar, plot_spearman_results,\n",
    "    plot_final_summary_dashboard\n",
    ")\n",
    "%matplotlib inline\n",
    "plt.rcParams['figure.dpi'] = 100\n",
    "\n",
    "df         = pd.read_csv(DATA_PROC_DIR / 'standings_features.csv')\n",
    "summary_df = pd.read_csv(DATA_PROC_DIR / 'hypothesis_summary.csv')\n",
    "top4       = extract_top4(df)\n",
    "print(f'Data loaded: {len(df)} rows, {len(top4)} top-4 rows')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_ga_distribution(df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_correlation_heatmap(df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_ga_vs_points_scatter(df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_champion_def_rank_heatmap(summary_df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_top4_defensive_bars(df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_champion_ga_trend(df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_defensive_radar(top4); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_hypothesis_summary_bar(summary_df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_spearman_results(df); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null, "metadata": {}, "outputs": [],
   "source": [
    "plot_final_summary_dashboard(df, summary_df); plt.show()\n",
    "print('All 10 figures saved to outputs/figures/')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Conclusions\n",
    "\n",
    "### H1: Did the best defensive team win the title?\n",
    "- % of seasons where rank-1 defence won: `[fill after run]`\n",
    "- % of seasons where top-3 defence won: `[fill after run]`\n",
    "\n",
    "### H2: Is defensive rank correlated with final position?\n",
    "- Spearman rho range across leagues: `[fill after run]`\n",
    "- All leagues significant at 0.05: `[fill after run]`\n",
    "\n",
    "### H3: Can defence alone predict Top 4?\n",
    "- Logistic regression accuracy: `[fill after run]`\n",
    "- Baseline accuracy: `[fill after run]`\n",
    "\n",
    "---\n",
    "Full narrative in docs/PROJECT_DETAIL.md"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
  "language_info": {"name": "python", "version": "3.10.0"}
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
